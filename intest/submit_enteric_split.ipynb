# %%
import getpass
import numpy as np
import os
import pandas as pd
import polars as pl
import pymysql 
import re
import shutil
import subprocess
import time

from datetime import datetime
from db_queries import get_demographics, get_ids, get_location_metadata, get_population, get_sequela_metadata
from save_results import save_results_epi, save_results_cod

release = 16
level_3 = 'ints' # set to either 'ints' or 'intest'
clear_output_dir = False
best = True

bundles = {'intest': 556, 'ints':3785}
xwalks = {'intest': 17891, 'ints': 7298}
    
input_dir = f'/ihme/scratch/users/stanaway/{level_3}/release_{release}/inputs/'
output_dir = f'/ihme/scratch/users/stanaway/{level_3}/release_{release}/draws/'

# Make a list of all of the cause and modelable entity ids for which we'll produce output
seq_meta = get_sequela_metadata(sequela_set_id=2, release_id=release)

if level_3 == 'intest':
    cid_list = [319, 320]
    seq_meta = seq_meta.loc[seq_meta.cause_id.isin(cid_list), 'modelable_entity_id'].tolist()
    upload_ids = cid_list + seq_meta
    output_ids = upload_ids + [2523, 23991, 23992]
elif level_3 == 'ints':
    cid_list = [959]
    seq_meta = seq_meta.loc[seq_meta.cause_id.isin(cid_list), 'modelable_entity_id'].tolist()
    upload_ids = cid_list + seq_meta + [27540, 28000]
    intermediate_ids = [9999, 9959, 196800, 196801]
    output_ids = upload_ids + intermediate_ids
else:
    print('Value of level_3 must be either "intest" or "ints".')

for output_id in output_ids + ['model_info']:
    if clear_output_dir == True:
        shutil.rmtree(os.path.join(output_dir, str(output_id)))
    os.makedirs(os.path.join(output_dir, str(output_id)), exist_ok = True)
    
    
cod_demog = get_demographics(gbd_team="cod", release_id = release)
locs = cod_demog['location_id']

if level_3 == 'intest':
    loc_meta = get_location_metadata(35, release_id = release)
    ind_locs = loc_meta[loc_meta.path_to_top_parent.str.contains(',163,')]['location_id'].tolist()

            
user = getpass.getuser()

# %%
launch_time = datetime.now()

for loc in locs:
    if level_3 == 'intest' and loc in ind_locs:
        mem = '100G'
    else:
        mem = '20G'

    submission_list = ['sbatch', '-J', f'{level_3}_{loc}', '-e', f'/ihme/temp/slurmoutput/{user}/errors/%x.e%j.txt',
                       '-o', f'/ihme/temp/slurmoutput/{user}/output/%x.o%j.txt', '-A', 'proj_erf',
                       f'--mem={mem}', '-c', '4', '-t', '600', '-p', 'all.q', 
                       '/ihme/homes/stanaway/py_shell.sh ' +  '/ihme/homes/stanaway/enteric_split.py ' + str(loc) + ' ' + str(release) + ' ' + str(level_3)]
    
    submission_str = " ".join(submission_list)
    os.system(submission_str)
    
while True:
    time.sleep(30)
    
    all_jobs = subprocess.check_output('squeue --me -o "%j"', shell = True)
    all_jobs = all_jobs.decode().split("\n")[1:]

    matching_jobs = [job for job in all_jobs if re.match(f"^{level_3}", job)]
    if len(matching_jobs) == 0:
        print('All jobs done running. Checking output files.')
        break
    else:
        print('Jobs still running.  Will check again in a minute.')
# Out:
# Submitted batch job 65794280
# Submitted batch job 65794281
# Submitted batch job 65794282
# Submitted batch job 65794283
# Submitted batch job 65794284
# Submitted batch job 65794285
# Submitted batch job 65794286
# Submitted batch job 65794287
# Submitted batch job 65794288
# Submitted batch job 65794289
# Submitted batch job 65794290
# Submitted batch job 65794291
# Submitted batch job 65794292
# Submitted batch job 65794293
# Submitted batch job 65794294
# Submitted batch job 65794295
# Submitted batch job 65794296
# Submitted batch job 65794297
# Submitted batch job 65794298
# Submitted batch job 65794299
# Submitted batch job 65794300
# Submitted batch job 65794301
# Submitted batch job 65794302
# Submitted batch job 65794303
# Submitted batch job 65794304
# Submitted batch job 65794305
# Submitted batch job 65794306
# Submitted batch job 65794307
# Submitted batch job 65794308
# Submitted batch job 65794309
# Submitted batch job 65794310
# Submitted batch job 65794311
# Submitted batch job 65794312
# Submitted batch job 65794313
# Submitted batch job 65794314
# Submitted batch job 65794315
# Submitted batch job 65794316
# Submitted batch job 65794317
# Submitted batch job 65794318
# Submitted batch job 65794319
# Submitted batch job 65794320
# Submitted batch job 65794321
# Submitted batch job 65794322
# Submitted batch job 65794323
# Submitted batch job 65794324
# Submitted batch job 65794325
# Submitted batch job 65794326
# Submitted batch job 65794327
# Submitted batch job 65794328
# Submitted batch job 65794329
# Submitted batch job 65794330
# Submitted batch job 65794331
# Submitted batch job 65794332
# Submitted batch job 65794333
# Submitted batch job 65794334
# Submitted batch job 65794335
# Submitted batch job 65794336
# Submitted batch job 65794337
# Submitted batch job 65794338
# Submitted batch job 65794339
# Submitted batch job 65794340
# Submitted batch job 65794341
# Submitted batch job 65794342
# Submitted batch job 65794343
# Submitted batch job 65794344
# Submitted batch job 65794345
# Submitted batch job 65794346
# Submitted batch job 65794347
# Submitted batch job 65794348
# Submitted batch job 65794349
# Submitted batch job 65794350
# Submitted batch job 65794351
# Submitted batch job 65794352
# Submitted batch job 65794353
# Submitted batch job 65794354
# Submitted batch job 65794355
# Submitted batch job 65794356
# Submitted batch job 65794357
# Submitted batch job 65794358
# Submitted batch job 65794359
# Submitted batch job 65794360
# Submitted batch job 65794361
# Submitted batch job 65794362
# Submitted batch job 65794363
# Submitted batch job 65794364
# Submitted batch job 65794365
# Submitted batch job 65794366
# Submitted batch job 65794367
# Submitted batch job 65794368
# Submitted batch job 65794369
# Submitted batch job 65794370
# Submitted batch job 65794371
# Submitted batch job 65794372
# Submitted batch job 65794373
# Submitted batch job 65794374
# Submitted batch job 65794375
# Submitted batch job 65794376
# Submitted batch job 65794377
# Submitted batch job 65794378
# Submitted batch job 65794379
# Submitted batch job 65794380
# Submitted batch job 65794381
# Submitted batch job 65794382
# Submitted batch job 65794383
# Submitted batch job 65794384
# Submitted batch job 65794385
# Submitted batch job 65794386
# Submitted batch job 65794387
# Submitted batch job 65794388
# Submitted batch job 65794389
# Submitted batch job 65794390
# Submitted batch job 65794391
# Submitted batch job 65794392
# Submitted batch job 65794393
# Submitted batch job 65794394
# Submitted batch job 65794395
# Submitted batch job 65794396
# Submitted batch job 65794397
# Submitted batch job 65794398
# Submitted batch job 65794399
# Submitted batch job 65794400
# Submitted batch job 65794401
# Submitted batch job 65794402
# Submitted batch job 65794403
# Submitted batch job 65794404
# Submitted batch job 65794405
# Submitted batch job 65794406
# Submitted batch job 65794407
# Submitted batch job 65794408
# Submitted batch job 65794409
# Submitted batch job 65794410
# Submitted batch job 65794411
# Submitted batch job 65794412
# Submitted batch job 65794413
# Submitted batch job 65794414
# Submitted batch job 65794415
# Submitted batch job 65794416
# Submitted batch job 65794417
# Submitted batch job 65794418
# Submitted batch job 65794419
# Submitted batch job 65794420
# Submitted batch job 65794421
# Submitted batch job 65794422
# Submitted batch job 65794423
# Submitted batch job 65794424
# Submitted batch job 65794425
# Submitted batch job 65794426
# Submitted batch job 65794427
# Submitted batch job 65794428
# Submitted batch job 65794429
# Submitted batch job 65794430
# Submitted batch job 65794431
# Submitted batch job 65794432
# Submitted batch job 65794433
# Submitted batch job 65794434
# Submitted batch job 65794435
# Submitted batch job 65794436
# Submitted batch job 65794437
# Submitted batch job 65794438
# Submitted batch job 65794439
# Submitted batch job 65794440
# Submitted batch job 65794441
# Submitted batch job 65794442
# Submitted batch job 65794443
# Submitted batch job 65794444
# Submitted batch job 65794445
# Submitted batch job 65794446
# Submitted batch job 65794447
# Submitted batch job 65794448
# Submitted batch job 65794449
# Submitted batch job 65794450
# Submitted batch job 65794451
# Submitted batch job 65794452
# Submitted batch job 65794453
# Submitted batch job 65794454
# Submitted batch job 65794455
# Submitted batch job 65794456
# Submitted batch job 65794457
# Submitted batch job 65794458
# Submitted batch job 65794459
# Submitted batch job 65794460
# Submitted batch job 65794461
# Submitted batch job 65794462
# Submitted batch job 65794463
# Submitted batch job 65794464
# Submitted batch job 65794465
# Submitted batch job 65794466
# Submitted batch job 65794467
# Submitted batch job 65794468
# Submitted batch job 65794469
# Submitted batch job 65794470
# Submitted batch job 65794471
# Submitted batch job 65794472
# Submitted batch job 65794473
# Submitted batch job 65794474
# Submitted batch job 65794475
# Submitted batch job 65794476
# Submitted batch job 65794477
# Submitted batch job 65794478
# Submitted batch job 65794479
# Submitted batch job 65794480
# Submitted batch job 65794481
# Submitted batch job 65794482
# Submitted batch job 65794483
# Submitted batch job 65794484
# Submitted batch job 65794485
# Submitted batch job 65794486
# Submitted batch job 65794487
# Submitted batch job 65794488
# Submitted batch job 65794489
# Submitted batch job 65794490
# Submitted batch job 65794491
# Submitted batch job 65794492
# Submitted batch job 65794493
# Submitted batch job 65794494
# Submitted batch job 65794495
# Submitted batch job 65794496
# Submitted batch job 65794497
# Submitted batch job 65794498
# Submitted batch job 65794499
# Submitted batch job 65794500
# Submitted batch job 65794501
# Submitted batch job 65794502
# Submitted batch job 65794503
# Submitted batch job 65794504
# Submitted batch job 65794505
# Submitted batch job 65794506
# Submitted batch job 65794507
# Submitted batch job 65794508
# Submitted batch job 65794509
# Submitted batch job 65794510
# Submitted batch job 65794511
# Submitted batch job 65794512
# Submitted batch job 65794513
# Submitted batch job 65794514
# Submitted batch job 65794515
# Submitted batch job 65794516
# Submitted batch job 65794517
# Submitted batch job 65794518
# Submitted batch job 65794519
# Submitted batch job 65794520
# Submitted batch job 65794521
# Submitted batch job 65794522
# Submitted batch job 65794523
# Submitted batch job 65794524
# Submitted batch job 65794525
# Submitted batch job 65794526
# Submitted batch job 65794527
# Submitted batch job 65794528
# Submitted batch job 65794529
# Submitted batch job 65794530
# Submitted batch job 65794531
# Submitted batch job 65794532
# Submitted batch job 65794533
# Submitted batch job 65794534
# Submitted batch job 65794535
# Submitted batch job 65794536
# Submitted batch job 65794537
# Submitted batch job 65794538
# Submitted batch job 65794539
# Submitted batch job 65794540
# Submitted batch job 65794541
# Submitted batch job 65794542
# Submitted batch job 65794543
# Submitted batch job 65794544
# Submitted batch job 65794545
# Submitted batch job 65794546
# Submitted batch job 65794547
# Submitted batch job 65794548
# Submitted batch job 65794549
# Submitted batch job 65794550
# Submitted batch job 65794551
# Submitted batch job 65794552
# Submitted batch job 65794553
# Submitted batch job 65794554
# Submitted batch job 65794555
# Submitted batch job 65794556
# Submitted batch job 65794557
# Submitted batch job 65794558
# Submitted batch job 65794559
# Submitted batch job 65794560
# Submitted batch job 65794561
# Submitted batch job 65794562
# Submitted batch job 65794563
# Submitted batch job 65794564
# Submitted batch job 65794565
# Submitted batch job 65794566
# Submitted batch job 65794567
# Submitted batch job 65794568
# Submitted batch job 65794569
# Submitted batch job 65794570
# Submitted batch job 65794571
# Submitted batch job 65794572
# Submitted batch job 65794573
# Submitted batch job 65794574
# Submitted batch job 65794575
# Submitted batch job 65794576
# Submitted batch job 65794577
# Submitted batch job 65794578
# Submitted batch job 65794579
# Submitted batch job 65794580
# Submitted batch job 65794581
# Submitted batch job 65794582
# Submitted batch job 65794583
# Submitted batch job 65794584
# Submitted batch job 65794585
# Submitted batch job 65794586
# Submitted batch job 65794587
# Submitted batch job 65794588
# Submitted batch job 65794589
# Submitted batch job 65794590
# Submitted batch job 65794591
# Submitted batch job 65794592
# Submitted batch job 65794593
# Submitted batch job 65794594
# Submitted batch job 65794595
# Submitted batch job 65794596
# Submitted batch job 65794597
# Submitted batch job 65794598
# Submitted batch job 65794599
# Submitted batch job 65794600
# Submitted batch job 65794601
# Submitted batch job 65794602
# Submitted batch job 65794603
# Submitted batch job 65794604
# Submitted batch job 65794605
# Submitted batch job 65794606
# Submitted batch job 65794607
# Submitted batch job 65794608
# Submitted batch job 65794609
# Submitted batch job 65794610
# Submitted batch job 65794611
# Submitted batch job 65794612
# Submitted batch job 65794613
# Submitted batch job 65794614
# Submitted batch job 65794615
# Submitted batch job 65794616
# Submitted batch job 65794617
# Submitted batch job 65794618
# Submitted batch job 65794619
# Submitted batch job 65794620
# Submitted batch job 65794621
# Submitted batch job 65794622
# Submitted batch job 65794623
# Submitted batch job 65794624
# Submitted batch job 65794625
# Submitted batch job 65794626
# Submitted batch job 65794627
# Submitted batch job 65794628
# Submitted batch job 65794629
# Submitted batch job 65794630
# Submitted batch job 65794631
# Submitted batch job 65794632
# Submitted batch job 65794633
# Submitted batch job 65794634
# Submitted batch job 65794635
# Submitted batch job 65794636
# Submitted batch job 65794637
# Submitted batch job 65794638
# Submitted batch job 65794639
# Submitted batch job 65794640
# Submitted batch job 65794641
# Submitted batch job 65794642
# Submitted batch job 65794643
# Submitted batch job 65794644
# Submitted batch job 65794645
# Submitted batch job 65794646
# Submitted batch job 65794647
# Submitted batch job 65794648
# Submitted batch job 65794649
# Submitted batch job 65794650
# Submitted batch job 65794651
# Submitted batch job 65794652
# Submitted batch job 65794653
# Submitted batch job 65794654
# Submitted batch job 65794655
# Submitted batch job 65794656
# Submitted batch job 65794657
# Submitted batch job 65794658
# Submitted batch job 65794659
# Submitted batch job 65794660
# Submitted batch job 65794661
# Submitted batch job 65794662
# Submitted batch job 65794663
# Submitted batch job 65794664
# Submitted batch job 65794665
# Submitted batch job 65794666
# Submitted batch job 65794667
# Submitted batch job 65794668
# Submitted batch job 65794669
# Submitted batch job 65794670
# Submitted batch job 65794671
# Submitted batch job 65794672
# Submitted batch job 65794673
# Submitted batch job 65794674
# Submitted batch job 65794675
# Submitted batch job 65794676
# Submitted batch job 65794677
# Submitted batch job 65794678
# Submitted batch job 65794679
# Submitted batch job 65794680
# Submitted batch job 65794681
# Submitted batch job 65794682
# Submitted batch job 65794683
# Submitted batch job 65794684
# Submitted batch job 65794685
# Submitted batch job 65794686
# Submitted batch job 65794687
# Submitted batch job 65794688
# Submitted batch job 65794689
# Submitted batch job 65794690
# Submitted batch job 65794691
# Submitted batch job 65794692
# Submitted batch job 65794693
# Submitted batch job 65794694
# Submitted batch job 65794695
# Submitted batch job 65794696
# Submitted batch job 65794697
# Submitted batch job 65794698
# Submitted batch job 65794699
# Submitted batch job 65794700
# Submitted batch job 65794701
# Submitted batch job 65794702
# Submitted batch job 65794703
# Submitted batch job 65794704
# Submitted batch job 65794705
# Submitted batch job 65794706
# Submitted batch job 65794707
# Submitted batch job 65794708
# Submitted batch job 65794709
# Submitted batch job 65794710
# Submitted batch job 65794711
# Submitted batch job 65794712
# Submitted batch job 65794713
# Submitted batch job 65794714
# Submitted batch job 65794715
# Submitted batch job 65794716
# Submitted batch job 65794717
# Submitted batch job 65794718
# Submitted batch job 65794719
# Submitted batch job 65794720
# Submitted batch job 65794721
# Submitted batch job 65794722
# Submitted batch job 65794723
# Submitted batch job 65794724
# Submitted batch job 65794725
# Submitted batch job 65794726
# Submitted batch job 65794727
# Submitted batch job 65794728
# Submitted batch job 65794729
# Submitted batch job 65794730
# Submitted batch job 65794731
# Submitted batch job 65794732
# Submitted batch job 65794733
# Submitted batch job 65794734
# Submitted batch job 65794735
# Submitted batch job 65794736
# Submitted batch job 65794737
# Submitted batch job 65794738
# Submitted batch job 65794739
# Submitted batch job 65794740
# Submitted batch job 65794741
# Submitted batch job 65794742
# Submitted batch job 65794743
# Submitted batch job 65794744
# Submitted batch job 65794745
# Submitted batch job 65794746
# Submitted batch job 65794747
# Submitted batch job 65794748
# Submitted batch job 65794749
# Submitted batch job 65794750
# Submitted batch job 65794751
# Submitted batch job 65794752
# Submitted batch job 65794753
# Submitted batch job 65794754
# Submitted batch job 65794755
# Submitted batch job 65794756
# Submitted batch job 65794757
# Submitted batch job 65794758
# Submitted batch job 65794759
# Submitted batch job 65794760
# Submitted batch job 65794761
# Submitted batch job 65794762
# Submitted batch job 65794763
# Submitted batch job 65794764
# Submitted batch job 65794765
# Submitted batch job 65794766
# Submitted batch job 65794767
# Submitted batch job 65794768
# Submitted batch job 65794769
# Submitted batch job 65794770
# Submitted batch job 65794771
# Submitted batch job 65794772
# Submitted batch job 65794773
# Submitted batch job 65794774
# Submitted batch job 65794775
# Submitted batch job 65794776
# Submitted batch job 65794777
# Submitted batch job 65794778
# Submitted batch job 65794779
# Submitted batch job 65794780
# Submitted batch job 65794781
# Submitted batch job 65794782
# Submitted batch job 65794783
# Submitted batch job 65794784
# Submitted batch job 65794785
# Submitted batch job 65794786
# Submitted batch job 65794787
# Submitted batch job 65794788
# Submitted batch job 65794789
# Submitted batch job 65794790
# Submitted batch job 65794791
# Submitted batch job 65794792
# Submitted batch job 65794793
# Submitted batch job 65794794
# Submitted batch job 65794795
# Submitted batch job 65794796
# Submitted batch job 65794797
# Submitted batch job 65794798
# Submitted batch job 65794799
# Submitted batch job 65794800
# Submitted batch job 65794801
# Submitted batch job 65794802
# Submitted batch job 65794803
# Submitted batch job 65794804
# Submitted batch job 65794805
# Submitted batch job 65794806
# Submitted batch job 65794807
# Submitted batch job 65794808
# Submitted batch job 65794809
# Submitted batch job 65794810
# Submitted batch job 65794811
# Submitted batch job 65794812
# Submitted batch job 65794813
# Submitted batch job 65794814
# Submitted batch job 65794815
# Submitted batch job 65794816
# Submitted batch job 65794817
# Submitted batch job 65794818
# Submitted batch job 65794819
# Submitted batch job 65794820
# Submitted batch job 65794821
# Submitted batch job 65794822
# Submitted batch job 65794823
# Submitted batch job 65794824
# Submitted batch job 65794825
# Submitted batch job 65794826
# Submitted batch job 65794827
# Submitted batch job 65794828
# Submitted batch job 65794829
# Submitted batch job 65794830
# Submitted batch job 65794831
# Submitted batch job 65794832
# Submitted batch job 65794833
# Submitted batch job 65794834
# Submitted batch job 65794835
# Submitted batch job 65794836
# Submitted batch job 65794837
# Submitted batch job 65794838
# Submitted batch job 65794839
# Submitted batch job 65794840
# Submitted batch job 65794841
# Submitted batch job 65794842
# Submitted batch job 65794843
# Submitted batch job 65794844
# Submitted batch job 65794845
# Submitted batch job 65794846
# Submitted batch job 65794847
# Submitted batch job 65794848
# Submitted batch job 65794849
# Submitted batch job 65794850
# Submitted batch job 65794851
# Submitted batch job 65794852
# Submitted batch job 65794853
# Submitted batch job 65794854
# Submitted batch job 65794855
# Submitted batch job 65794856
# Submitted batch job 65794857
# Submitted batch job 65794858
# Submitted batch job 65794859
# Submitted batch job 65794860
# Submitted batch job 65794861
# Submitted batch job 65794862
# Submitted batch job 65794863
# Submitted batch job 65794864
# Submitted batch job 65794865
# Submitted batch job 65794866
# Submitted batch job 65794867
# Submitted batch job 65794868
# Submitted batch job 65794869
# Submitted batch job 65794870
# Submitted batch job 65794871
# Submitted batch job 65794872
# Submitted batch job 65794873
# Submitted batch job 65794874
# Submitted batch job 65794875
# Submitted batch job 65794876
# Submitted batch job 65794877
# Submitted batch job 65794878
# Submitted batch job 65794879
# Submitted batch job 65794880
# Submitted batch job 65794881
# Submitted batch job 65794882
# Submitted batch job 65794883
# Submitted batch job 65794884
# Submitted batch job 65794885
# Submitted batch job 65794886
# Submitted batch job 65794887
# Submitted batch job 65794888
# Submitted batch job 65794889
# Submitted batch job 65794890
# Submitted batch job 65794891
# Submitted batch job 65794892
# Submitted batch job 65794893
# Submitted batch job 65794894
# Submitted batch job 65794895
# Submitted batch job 65794896
# Submitted batch job 65794897
# Submitted batch job 65794898
# Submitted batch job 65794899
# Submitted batch job 65794900
# Submitted batch job 65794901
# Submitted batch job 65794902
# Submitted batch job 65794903
# Submitted batch job 65794904
# Submitted batch job 65794905
# Submitted batch job 65794906
# Submitted batch job 65794907
# Submitted batch job 65794908
# Submitted batch job 65794909
# Submitted batch job 65794910
# Submitted batch job 65794911
# Submitted batch job 65794912
# Submitted batch job 65794913
# Submitted batch job 65794914
# Submitted batch job 65794915
# Submitted batch job 65794916
# Submitted batch job 65794917
# Submitted batch job 65794918
# Submitted batch job 65794919
# Submitted batch job 65794920
# Submitted batch job 65794921
# Submitted batch job 65794922
# Submitted batch job 65794923
# Submitted batch job 65794924
# Submitted batch job 65794925
# Submitted batch job 65794926
# Submitted batch job 65794927
# Submitted batch job 65794928
# Submitted batch job 65794929
# Submitted batch job 65794930
# Submitted batch job 65794931
# Submitted batch job 65794932
# Submitted batch job 65794933
# Submitted batch job 65794934
# Submitted batch job 65794935
# Submitted batch job 65794936
# Submitted batch job 65794937
# Submitted batch job 65794938
# Submitted batch job 65794939
# Submitted batch job 65794940
# Submitted batch job 65794941
# Submitted batch job 65794942
# Submitted batch job 65794943
# Submitted batch job 65794944
# Submitted batch job 65794945
# Submitted batch job 65794946
# Submitted batch job 65794947
# Submitted batch job 65794948
# Submitted batch job 65794949
# Submitted batch job 65794950
# Submitted batch job 65794951
# Submitted batch job 65794952
# Submitted batch job 65794953
# Submitted batch job 65794954
# Submitted batch job 65794955
# Submitted batch job 65794956
# Submitted batch job 65794957
# Submitted batch job 65794958
# Submitted batch job 65794959
# Submitted batch job 65794960
# Submitted batch job 65794961
# Submitted batch job 65794962
# Submitted batch job 65794963
# Submitted batch job 65794964
# Submitted batch job 65794965
# Submitted batch job 65794966
# Submitted batch job 65794967
# Submitted batch job 65794968
# Submitted batch job 65794969
# Submitted batch job 65794970
# Submitted batch job 65794971
# Submitted batch job 65794972
# Submitted batch job 65794973
# Submitted batch job 65794974
# Submitted batch job 65794975
# Submitted batch job 65794976
# Submitted batch job 65794977
# Submitted batch job 65794978
# Submitted batch job 65794979
# Submitted batch job 65794980
# Submitted batch job 65794981
# Submitted batch job 65794982
# Submitted batch job 65794983
# Submitted batch job 65794984
# Submitted batch job 65794985
# Submitted batch job 65794986
# Submitted batch job 65794987
# Submitted batch job 65794988
# Submitted batch job 65794989
# Submitted batch job 65794990
# Submitted batch job 65794991
# Submitted batch job 65794992
# Submitted batch job 65794993
# Submitted batch job 65794994
# Submitted batch job 65794995
# Submitted batch job 65794996
# Submitted batch job 65794997
# Submitted batch job 65794998
# Submitted batch job 65794999
# Submitted batch job 65795000
# Submitted batch job 65795001
# Submitted batch job 65795002
# Submitted batch job 65795003
# Submitted batch job 65795004
# Submitted batch job 65795005
# Submitted batch job 65795006
# Submitted batch job 65795007
# Submitted batch job 65795008
# Submitted batch job 65795009
# Submitted batch job 65795010
# Submitted batch job 65795011
# Submitted batch job 65795012
# Submitted batch job 65795013
# Submitted batch job 65795014
# Submitted batch job 65795015
# Submitted batch job 65795016
# Submitted batch job 65795017
# Submitted batch job 65795018
# Submitted batch job 65795019
# Submitted batch job 65795020
# Submitted batch job 65795021
# Submitted batch job 65795022
# Submitted batch job 65795023
# Submitted batch job 65795024
# Submitted batch job 65795025
# Submitted batch job 65795026
# Submitted batch job 65795027
# Submitted batch job 65795028
# Submitted batch job 65795029
# Submitted batch job 65795030
# Submitted batch job 65795031
# Submitted batch job 65795032
# Submitted batch job 65795033
# Submitted batch job 65795034
# Submitted batch job 65795035
# Submitted batch job 65795036
# Submitted batch job 65795037
# Submitted batch job 65795038
# Submitted batch job 65795039
# Submitted batch job 65795040
# Submitted batch job 65795041
# Submitted batch job 65795042
# Submitted batch job 65795043
# Submitted batch job 65795044
# Submitted batch job 65795045
# Submitted batch job 65795046
# Submitted batch job 65795047
# Submitted batch job 65795048
# Submitted batch job 65795049
# Submitted batch job 65795050
# Submitted batch job 65795051
# Submitted batch job 65795052
# Submitted batch job 65795053
# Submitted batch job 65795054
# Submitted batch job 65795055
# Submitted batch job 65795056
# Submitted batch job 65795057
# Submitted batch job 65795058
# Submitted batch job 65795059
# Submitted batch job 65795060
# Submitted batch job 65795061
# Submitted batch job 65795062
# Submitted batch job 65795063
# Submitted batch job 65795064
# Submitted batch job 65795065
# Submitted batch job 65795066
# Submitted batch job 65795067
# Submitted batch job 65795068
# Submitted batch job 65795069
# Submitted batch job 65795070
# Submitted batch job 65795071
# Submitted batch job 65795072
# Submitted batch job 65795073
# Submitted batch job 65795074
# Submitted batch job 65795075
# Submitted batch job 65795076
# Submitted batch job 65795077
# Submitted batch job 65795078
# Submitted batch job 65795079
# Submitted batch job 65795080
# Submitted batch job 65795081
# Submitted batch job 65795082
# Submitted batch job 65795083
# Submitted batch job 65795084
# Submitted batch job 65795085
# Submitted batch job 65795086
# Submitted batch job 65795087
# Submitted batch job 65795088
# Submitted batch job 65795089
# Submitted batch job 65795090
# Submitted batch job 65795091
# Submitted batch job 65795092
# Submitted batch job 65795093
# Submitted batch job 65795094
# Submitted batch job 65795095
# Submitted batch job 65795096
# Submitted batch job 65795097
# Submitted batch job 65795098
# Submitted batch job 65795099
# Submitted batch job 65795100
# Submitted batch job 65795101
# Submitted batch job 65795102
# Submitted batch job 65795103
# Submitted batch job 65795104
# Submitted batch job 65795105
# Submitted batch job 65795106
# Submitted batch job 65795107
# Submitted batch job 65795108
# Submitted batch job 65795109
# Submitted batch job 65795110
# Submitted batch job 65795111
# Submitted batch job 65795112
# Submitted batch job 65795113
# Submitted batch job 65795114
# Submitted batch job 65795115
# Submitted batch job 65795116
# Submitted batch job 65795117
# Submitted batch job 65795118
# Submitted batch job 65795119
# Submitted batch job 65795120
# Submitted batch job 65795121
# Submitted batch job 65795122
# Jobs still running.  Will check again in a minute.
# Jobs still running.  Will check again in a minute.
# Jobs still running.  Will check again in a minute.
# Jobs still running.  Will check again in a minute.
# All jobs done running. Checking output files.

# %%
def file_checker(file, launch):
    exists = os.path.isfile(file)
    if exists: 
        mtime = datetime.fromtimestamp(os.path.getmtime(file))
        if mtime > launch_time:
            return 'new'
        else:
            return 'old'
    else:
        return 'missing'

    
checks = [[id, loc, file_checker(os.path.join(output_dir, str(id), f"{loc}.csv"), launch_time)] for id in output_ids for loc in locs]
checks = pd.DataFrame(checks, columns = ['meid', 'location_id', 'status'])
checks['complete'] = checks['status'] == 'new'

ready = checks.groupby(['meid'])['complete'].mean().reset_index()

meids_to_upload = ready.loc[ready.complete==1, 'meid']
meids_to_upload = [x for x in meids_to_upload if x in upload_ids]
print(checks.groupby('meid')['status'].value_counts())
# Out:
# meid   status
# 319    new       843
# 320    new       843
# 1249   new       843
# 1250   new       843
# 1251   new       843
# 1253   new       843
# 1254   new       843
# 1255   new       843
# 1256   new       843
# 2523   new       843
# 3134   new       843
# 23991  new       843
# 23992  new       843
# Name: status, dtype: int64

# %%
print(meids_to_upload)
print(upload_ids)
missing_upload_ids = set(upload_ids) - set(meids_to_upload)
if len(missing_upload_ids) == 0:
    print("Results are complete for all upload IDs")
else:
    print("The following upload ids do not have complete results: " + str(missing_upload_ids))
# Out:
# [319, 320, 1249, 1250, 1251, 1253, 1254, 1255, 1256, 3134]
# [319, 320, 3134, 1251, 1249, 1250, 1256, 1253, 1254, 1255]
# Results are complete for all upload IDs

# %%
model_info = (pl.scan_csv(os.path.join(output_dir, 'model_info', '*.csv')).collect(streaming = True)).unique()
label = []
for tool, group in model_info.group_by('tool'):
    label.append(tool + ' = ' + ', '.join([str(id) for id in group['model_version_id']]))

label = '; and '.join(label)
description = f'Natural hx / CODEm hybrid using {label}, with python pipeline'
print(description)
# Out:
# Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline

# %%
for id in meids_to_upload:
    if id in cid_list:
        type = 'cod'
        mem = '200G'
        measures = 1

    else:
        type = 'epi'
        mem = '100G'

        m_test = pl.read_csv(os.path.join(output_dir, str(id), '161.csv'))
        measures = ' '.join(map(str, m_test['measure_id'].unique()))

    best = 'True'

    submission_list = ['sbatch', '-J', f'upload_{id}', '-e', f'/ihme/temp/slurmoutput/{user}/errors/%x.e%j.txt',
                       '-o', f'/ihme/temp/slurmoutput/{user}/output/%x.o%j.txt', '-A', 'proj_erf',
                       f'--mem={mem}', '-c', '4', '-t', '1000', '-p', 'all.q', 
                       '/ihme/homes/stanaway/py_shell.sh ' +  '/ihme/homes/stanaway/apTest.py ' + 
                       f'--type {type} --id {id} --path {os.path.join(output_dir, str(id))} --description "{description}" ' +
                       f'--measure {measures} --best {best} --release {release} --bundle {bundles[level_3]} --xwalk {xwalks[level_3]}']

    submission_str = " ".join(submission_list)
    print(submission_str)
    os.system(submission_str)
# Out:
# sbatch -J upload_1249 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1249 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1249 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795407
# sbatch -J upload_1250 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1250 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1250 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795408
# sbatch -J upload_1251 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1251 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1251 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795409
# sbatch -J upload_1253 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1253 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1253 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795410
# sbatch -J upload_1254 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1254 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1254 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795411
# sbatch -J upload_1255 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1255 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1255 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795412
# sbatch -J upload_1256 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 1256 --path /ihme/scratch/users/stanaway/intest/release_16/draws/1256 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795413
# sbatch -J upload_3134 -e /ihme/temp/slurmoutput/stanaway/errors/%x.e%j.txt -o /ihme/temp/slurmoutput/stanaway/output/%x.o%j.txt -A proj_erf --mem=100G -c 4 -t 1000 -p all.q /ihme/homes/stanaway/py_shell.sh /ihme/homes/stanaway/apTest.py --type epi --id 3134 --path /ihme/scratch/users/stanaway/intest/release_16/draws/3134 --description "Natural hx / CODEm hybrid using codem = 739996, 739994, 739997, 740256; and dismod = 799168, 799167, 799169, with python pipeline" --measure 5 6 --best True --release 16 --bundle 556 --xwalk 17891
# Submitted batch job 65795414

# %%
def get_latest_dr_codem_models(cause_ids, release):
    cause_ids_str = ", ".join([str(x) for x in cause_ids])
    varlist = ['model_version_id', 'cause_id', 'sex_id', 'date_inserted']
    db = pymysql.connect(host = 'modeling-cod-db.ihme.washington.edu', user = 'dbview', password = 'E3QNSLvQTRJm', database = 'cod') 
    
    with db:
        with db.cursor() as cursor:
            cursor.execute(f'SELECT {", ".join(varlist)} FROM model_version \
            WHERE cause_id IN ({cause_ids_str}) AND model_version_type_id = 2 AND status IN (1,2) AND release_id = {release}') 
    
            # Fetch all rows of data, put them in a data frame and add column names
            cod_models = pd.DataFrame(cursor.fetchall(), columns = varlist)
    
    latest = cod_models.groupby(['cause_id', 'sex_id'])['model_version_id'].max()
    cod_models = cod_models[cod_models.model_version_id.isin(latest)]
    cod_models = cod_models.merge(get_ids('sex'), on = 'sex_id', how = 'left') \
                           .merge(get_ids('cause'), on = 'cause_id', how = 'left')
    cod_models.loc[cod_models.acause == 'intest_paratyph', 'acause'] = 'intest_paratyphoid'
    cod_models['dict_key'] = (cod_models['sex'].astype(str)).str.lower() + "_" + cod_models['acause'].str.replace('intest_', '')
    
    cids = cod_models[['dict_key','model_version_id']].set_index('dict_key')['model_version_id'].to_dict() 
    return cids

#codem_ids = [get_latest_dr_codem_models(c) for c in [319, 320, 959]]
#codem_ids = get_latest_dr_codem_models([319, 320, 959])
#print(codem_ids)
